# %% [markdown]
# # Task 3
# ### Here I use the Greykite timeseries forecasting model developed by LinkedIn:
# * Github: https://github.com/linkedin/greykite
# * Paper 1: https://arxiv.org/pdf/2207.07788.pdf
# * Paper 2: https://arxiv.org/pdf/2105.01098.pdf

# %% [markdown]
# ### The two models developed are simple forecasting models based on time and value counts of and volume of people in the office per day.
# ### More sophisticated models can be developed that may use:
# * Event information such as holidays
# * Seasonality to account for time of year, weekly and monthly trends
# * Regressors (features) that assist this prediction.

# %% [markdown]
# ### The Mean Absolute Percentage Error for the first approach was 53.97
# ### For the second approach which removed outliers in the dataset the MAPE score was improved to 28.45
#
# #### You can find prediction plots and results dataframes in the cells below.
#
# # I found that in the 100 days prediction horizon that Tuesday will be the busiest day in the office - Result at bottom of notebook

# %%
from collections import defaultdict
import warnings
import pandas as pd
warnings.filterwarnings("ignore")
import pandas as pd
import plotly
from greykite.framework.templates.autogen.forecast_config import ForecastConfig
from greykite.framework.templates.autogen.forecast_config import MetadataParam
from greykite.framework.templates.forecaster import Forecaster 
from greykite.framework.templates.model_templates import ModelTemplateEnum
from greykite.framework.utils.result_summary import summarize_grid_search_results

from greykite.algo.forecast.silverkite.constants.silverkite_holiday import SilverkiteHoliday
from greykite.framework.templates.autogen.forecast_config import ModelComponentsParam

# %% [markdown]
# ### Initial data loading and formatting

# %%
original_df = pd.read_csv('data.csv', header=0)
original_df.head()
# Out:
#                       user.email user.firstName user.lastName  \
# 0  ciaran.starrs+22@chargifi.com         Ciaran        Starrs
# 1   ciaran.starrs+n43@kadence.co    Gerraintttt     Arlington
# 2  ciaran.starrs+22@chargifi.com         Ciaran        Starrs
# 3  ciaran.starrs+22@chargifi.com         Ciaran        Starrs
# 4  ciaran.starrs+22@chargifi.com         Ciaran        Starrs
#
#   guest.emailAddress guest.firstName guest.lastName space.name space.type  \
# 0                NaN             NaN            NaN    Desk 02       desk
# 1                NaN             NaN            NaN    Desk 05       desk
# 2                NaN             NaN            NaN    Desk 02       desk
# 3                NaN             NaN            NaN    Desk 04       desk
# 4                NaN             NaN            NaN    Desk 03       desk
#
#   space.floor.name space.neighborhood.name  ...                   end_date  \
# 0          Floor 1                 emotion  ...  2023-06-12T14:03:52+01:00
# 1          Floor 1   Private Neighbourhood  ...  2023-06-12T12:15:00+01:00
# 2          Floor 1                 emotion  ...  2023-06-12T11:30:51+01:00
# 3          Floor 1                     NaN  ...  2023-06-12T10:44:42+01:00
# 4          Floor 1                 emotion  ...  2023-06-12T10:20:56+01:00
#
#                   created_at             cancelled_date  \
# 0  2023-06-12T13:59:55+01:00                        NaN
# 1  2023-02-06T10:59:54+00:00  2023-02-14T11:29:40+00:00
# 2  2023-06-12T11:22:59+01:00                        NaN
# 3  2023-06-12T10:43:29+01:00                        NaN
# 4  2023-06-12T10:18:12+01:00                        NaN
#
#        first_checked_in_date      last_checked_out_date     status  \
# 0  2023-06-12T14:03:47+01:00  2023-06-12T14:03:52+01:00  completed
# 1                        NaN                        NaN  cancelled
# 2  2023-06-12T11:30:24+01:00  2023-06-12T11:30:51+01:00  completed
# 3  2023-06-12T10:44:30+01:00  2023-06-12T10:44:42+01:00  completed
# 4  2023-06-12T10:19:19+01:00  2023-06-12T10:20:56+01:00  completed
#
#                    status_label                 building.name building.city  \
# 0  Completed - manual check-out  Bell Yard Coffee - Bell Yard        London
# 1             Cancelled - other               Antrim Building       Belfast
# 2  Completed - manual check-out  Bell Yard Coffee - Bell Yard        London
# 3  Completed - manual check-out  Bell Yard Coffee - Bell Yard        London
# 4  Completed - manual check-out  Bell Yard Coffee - Bell Yard        London
#
#   building.countryName
# 0       United Kingdom
# 1       United Kingdom
# 2       United Kingdom
# 3       United Kingdom
# 4       United Kingdom
#
# [5 rows x 21 columns]

# %%
original_df["date_in"] = pd.to_datetime(original_df["start_date"])
original_df["date_in"] = pd.to_datetime(original_df["date_in"], utc=True).dt.date

# %%
df = original_df['date_in'].value_counts().to_frame()
df.rename(columns={"date_in":"n_bookings_day"}, inplace=True)
df["date_in"] = df.index
df.reset_index(inplace=True)

df.drop("index", axis=1, inplace=True)
df
# Out:
#      n_bookings_day     date_in
# 0              2049  2022-09-12
# 1              2046  2022-09-23
# 2               448  2022-02-15
# 3               428  2022-02-16
# 4               418  2022-11-16
# ..              ...         ...
# 719               1  2021-04-13
# 720               1  2021-05-24
# 721               1  2021-07-30
# 722               1  2021-08-23
# 723               1  2021-04-29
#
# [724 rows x 2 columns]

# %%
result = pd.merge(original_df, df, on="date_in")
result.rename(columns={"building.city":"building_city","building.name":"building_name","user.firstName":"user_firstName","space.type":"space_type"}, inplace=True)

# %%
result.head()
# Out:
#                       user.email user_firstName user.lastName  \
# 0  ciaran.starrs+22@chargifi.com         Ciaran        Starrs
# 1   ciaran.starrs+n43@kadence.co    Gerraintttt     Arlington
# 2  ciaran.starrs+22@chargifi.com         Ciaran        Starrs
# 3  ciaran.starrs+22@chargifi.com         Ciaran        Starrs
# 4  ciaran.starrs+22@chargifi.com         Ciaran        Starrs
#
#   guest.emailAddress guest.firstName guest.lastName space.name space_type  \
# 0                NaN             NaN            NaN    Desk 02       desk
# 1                NaN             NaN            NaN    Desk 05       desk
# 2                NaN             NaN            NaN    Desk 02       desk
# 3                NaN             NaN            NaN    Desk 04       desk
# 4                NaN             NaN            NaN    Desk 03       desk
#
#   space.floor.name space.neighborhood.name  ...             cancelled_date  \
# 0          Floor 1                 emotion  ...                        NaN
# 1          Floor 1   Private Neighbourhood  ...  2023-02-14T11:29:40+00:00
# 2          Floor 1                 emotion  ...                        NaN
# 3          Floor 1                     NaN  ...                        NaN
# 4          Floor 1                 emotion  ...                        NaN
#
#        first_checked_in_date      last_checked_out_date     status  \
# 0  2023-06-12T14:03:47+01:00  2023-06-12T14:03:52+01:00  completed
# 1                        NaN                        NaN  cancelled
# 2  2023-06-12T11:30:24+01:00  2023-06-12T11:30:51+01:00  completed
# 3  2023-06-12T10:44:30+01:00  2023-06-12T10:44:42+01:00  completed
# 4  2023-06-12T10:19:19+01:00  2023-06-12T10:20:56+01:00  completed
#
#                    status_label                 building_name building_city  \
# 0  Completed - manual check-out  Bell Yard Coffee - Bell Yard        London
# 1             Cancelled - other               Antrim Building       Belfast
# 2  Completed - manual check-out  Bell Yard Coffee - Bell Yard        London
# 3  Completed - manual check-out  Bell Yard Coffee - Bell Yard        London
# 4  Completed - manual check-out  Bell Yard Coffee - Bell Yard        London
#
#   building.countryName     date_in n_bookings_day
# 0       United Kingdom  2023-06-12             22
# 1       United Kingdom  2023-06-12             22
# 2       United Kingdom  2023-06-12             22
# 3       United Kingdom  2023-06-12             22
# 4       United Kingdom  2023-06-12             22
#
# [5 rows x 23 columns]

# %%
df = result[["date_in", "n_bookings_day", "building_city","building_name", "user.email", "building.countryName", 
"space_type", "user.lastName", "space.floor.name"]]

# %% [markdown]
# ### Setup some parameters to search - this requires a more robust experimentation phase to include events, seasonality and regressors (features)

# %%
model_components = ModelComponentsParam(
     autoregression=None,
     uncertainty={
         "uncertainty_dict": "auto",
     }
 )

# %%
metadata = MetadataParam(
     time_col="date_in",  # name of the time column
     value_col="n_bookings_day",  # name of the value column
     freq="D",  
 )

# %% [markdown]
# ## Run the main forecasting model

# %%
forecaster = Forecaster()
result_ts = forecaster.run_forecast_config(
     df=df,
     config=ForecastConfig(
         model_template=ModelTemplateEnum.SILVERKITE.name,
         forecast_horizon=100,  # forecasts 100 steps ahead
         coverage=0.95,  # 95% prediction intervals
         metadata_param=metadata,
         model_components_param=model_components,
    )
)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits

# %% [markdown]
# ## Input data time series - Notice the huge spikes in activity. The model struggles to incorporate these.

# %%
ts = result_ts.timeseries
fig = ts.plot()
plotly.io.show(fig)

# %%
print(ts.time_stats)         # time statistics
print(ts.value_stats)        # value statistics
print(ts.freq)               # frequency
print(ts.regressor_cols)     # available regressors
#print(ts.last_date_for_fit)  # last date with value_col
print(ts.last_date_for_reg)  # last date for any regressor
print(ts.df.head())          # the standardized dataset for forecasting
print(ts.fit_df.head())
# Out:
# {'gaps':    right_before_gap right_after_gap  gap_size
# 0        2021-03-12      2021-03-16       3.0
# 1        2021-03-18      2021-03-24       5.0
# 2        2021-03-24      2021-03-26       1.0
# 3        2021-03-26      2021-03-30       3.0
# 4        2021-03-31      2021-04-13      12.0
# 5        2021-04-13      2021-04-21       7.0
# 6        2021-04-23      2021-04-26       2.0
# 7        2021-04-26      2021-04-28       1.0
# 8        2021-04-30      2021-05-05       4.0
# 9        2021-05-06      2021-05-10       3.0
# 10       2021-05-11      2021-05-13       1.0
# 11       2021-05-13      2021-05-20       6.0
# 12       2021-05-21      2021-05-24       2.0
# 13       2021-05-25      2021-05-27       1.0
# 14       2021-05-28      2021-05-30       1.0
# 15       2021-05-30      2021-06-08       8.0
# 16       2021-06-08      2021-06-24      15.0
# 17       2021-06-24      2021-07-01       6.0
# 18       2021-07-01      2021-07-05       3.0
# 19       2021-07-09      2021-07-11       1.0
# 20       2021-07-16      2021-07-18       1.0
# 21       2021-07-23      2021-07-25       1.0
# 22       2021-07-30      2021-08-03       3.0
# 23       2021-08-04      2021-08-06       1.0
# 24       2021-08-06      2021-08-09       2.0
# 25       2021-08-13      2021-08-16       2.0
# 26       2021-08-17      2021-08-19       1.0
# 27       2021-08-20      2021-08-23       2.0
# 28       2021-08-27      2021-08-29       1.0, 'added_timepoints': 99, 'dropped_timepoints': 0, 'data_points': 823, 'mean_increment_secs': 86400.0, 'min_timestamp': Timestamp('2021-03-12 00:00:00'), 'max_timestamp': Timestamp('2023-06-12 00:00:00')}
# count     724.000000
# mean       67.955801
# std       118.043341
# min         1.000000
# 25%        34.000000
# 50%        48.000000
# 75%        74.250000
# max      2049.000000
# Name: y, dtype: float64
# D
# []
# None
#                    ts    y building.city         user.email  \
# 2021-03-12 2021-03-12  2.0        London  jordan@kadence.co
# 2021-03-13 2021-03-13  NaN           NaN                NaN
# 2021-03-14 2021-03-14  NaN           NaN                NaN
# 2021-03-15 2021-03-15  NaN           NaN                NaN
# 2021-03-16 2021-03-16  2.0        London                NaN
#
#            building.countryName space.type
# 2021-03-12       United Kingdom       desk
# 2021-03-13                  NaN        NaN
# 2021-03-14                  NaN        NaN
# 2021-03-15                  NaN        NaN
# 2021-03-16       United Kingdom       desk
#                    ts    y
# 2021-03-12 2021-03-12  2.0
# 2021-03-13 2021-03-13  NaN
# 2021-03-14 2021-03-14  NaN
# 2021-03-15 2021-03-15  NaN
# 2021-03-16 2021-03-16  2.0

# %% [markdown]
# ### Here, we see how the model fits to the training data and how prediction on the test splits varies from reality

# %%
backtest = result_ts.backtest
fig = backtest.plot()
plotly.io.show(fig)

# %% [markdown]
# ## Here, we have predictions from the next 100 days

# %%
forecast = result_ts.forecast
fig = forecast.plot()
plotly.io.show(fig)

# %% [markdown]
# #### Mean Absolute Percentage Error on test 53.97

# %%
grid_search = result_ts.grid_search
cv_results = summarize_grid_search_results(
     grid_search=grid_search,
     decimals=2,
     # The below saves space in the printed output. Remove to show all available metrics and columns.
     cv_report_metrics=None,
     column_order=["rank", "mean_test", "split_test", "mean_train", "split_train", "mean_fit_time", "mean_score_time", "params"])
 # Transposes to save space in the printed output
cv_results["params"] = cv_results["params"].astype(str)
cv_results.set_index("params", drop=True, inplace=True)
cv_results
# Out:
#         rank_test_MAPE  mean_test_MAPE        split_test_MAPE  \
# params
# []                   1           53.97  (55.96, 32.66, 73.29)
#
#         mean_train_MAPE         split_train_MAPE  mean_fit_time  \
# params
# []               105.01  (103.76, 88.82, 122.45)           3.07
#
#         mean_score_time
# params
# []                 0.74

# %% [markdown]
# # Model 2
# ### Here, we remove duplicate that have the same user firstname, lastname and date.time so we can reduce the number of outliers and produce a better fit

# %%
original_df = original_df.drop_duplicates()
original_df.head(2)
# Out:
#                       user.email user.firstName user.lastName  \
# 0  ciaran.starrs+22@chargifi.com         Ciaran        Starrs
# 1   ciaran.starrs+n43@kadence.co    Gerraintttt     Arlington
#
#   guest.emailAddress guest.firstName guest.lastName space.name space.type  \
# 0                NaN             NaN            NaN    Desk 02       desk
# 1                NaN             NaN            NaN    Desk 05       desk
#
#   space.floor.name space.neighborhood.name  ...                 created_at  \
# 0          Floor 1                 emotion  ...  2023-06-12T13:59:55+01:00
# 1          Floor 1   Private Neighbourhood  ...  2023-02-06T10:59:54+00:00
#
#               cancelled_date      first_checked_in_date  \
# 0                        NaN  2023-06-12T14:03:47+01:00
# 1  2023-02-14T11:29:40+00:00                        NaN
#
#        last_checked_out_date     status                  status_label  \
# 0  2023-06-12T14:03:52+01:00  completed  Completed - manual check-out
# 1                        NaN  cancelled             Cancelled - other
#
#                   building.name building.city building.countryName     date_in
# 0  Bell Yard Coffee - Bell Yard        London       United Kingdom  2023-06-12
# 1               Antrim Building       Belfast       United Kingdom  2023-06-12
#
# [2 rows x 22 columns]

# %%
df = df_2['date_in'].value_counts().to_frame()
df.rename(columns={"date_in":"n_bookings_day"}, inplace=True)
df["date_in"] = df.index
df.reset_index(inplace=True)

df.drop("index", axis=1, inplace=True)
df

# %%
import datetime
df_2 = pd.merge(original_df, df, on="date_in")
df_2['name'] = df_2.apply(lambda row: row['user.firstName'] + row["user.lastName"], axis=1)
df_2 = df_2.drop_duplicates(subset=["date_in", "name"])
df_2[df_2["date_in"] == datetime.date(2022, 9, 12)].head()
# Out:
#                           user.email user.firstName user.lastName  \
# 27641  ciaran.starrs+22@chargifi.com         Ciaran        Starrs
# 27644   ciaran.starrs+n45@kadence.co            Dax     Bamberger
# 27645         ryan+demo@chargifi.com           Ryan          Demo
# 29647    ciaran.starrs+sv@kadence.co           Stig     Bjarmabie
# 29648                            NaN            NaN           NaN
#
#       guest.emailAddress guest.firstName guest.lastName space.name space.type  \
# 27641                NaN             NaN            NaN   Desk 104       desk
# 27644                NaN             NaN            NaN    Desk 03       desk
# 27645                NaN             NaN            NaN  Desk 0001       desk
# 29647                NaN             NaN            NaN    Desk 02       desk
# 29648                NaN             NaN            NaN    Desk 02       desk
#
#               space.floor.name space.neighborhood.name  ...  \
# 27641  500 desks on this floor                     NaN  ...
# 27644                  Floor 1                 emotion  ...
# 27645                Big floor                     NaN  ...
# 29647                  Floor 1                     NaN  ...
# 29648                  Floor 1                     NaN  ...
#
#       first_checked_in_date last_checked_out_date       status  \
# 27641                   NaN                   NaN    cancelled
# 27644                   NaN                   NaN  no-check-in
# 27645                   NaN                   NaN  no-check-in
# 29647                   NaN                   NaN    cancelled
# 29648                   NaN                   NaN    cancelled
#
#             status_label                                    building.name  \
# 27641  Cancelled by user  Large number of desks on floors (do not delete)
# 27644        No check-in                     Bell Yard Coffee - Bell Yard
# 27645        No check-in             Ryan Building for bulk booking tests
# 29647  Cancelled - other                                  Antrim Building
# 29648  Cancelled - other                                  Antrim Building
#
#       building.city building.countryName     date_in n_bookings_day  \
# 27641  Peterborough       United Kingdom  2022-09-12             11
# 27644        London       United Kingdom  2022-09-12             11
# 27645     Salisbury       United Kingdom  2022-09-12             11
# 29647       Belfast       United Kingdom  2022-09-12             11
# 29648       Belfast       United Kingdom  2022-09-12             11
#
#                 name
# 27641   CiaranStarrs
# 27644   DaxBamberger
# 27645       RyanDemo
# 29647  StigBjarmabie
# 29648            NaN
#
# [5 rows x 24 columns]

# %%
df_2["date_in"].value_counts()
# Out:
# 2023-02-21    78
# 2023-02-23    78
# 2023-02-22    78
# 2023-02-20    55
# 2023-02-17    55
#               ..
# 2021-09-05     1
# 2021-03-31     1
# 2021-03-24     1
# 2021-05-13     1
# 2021-08-30     1
# Name: date_in, Length: 724, dtype: int64

# %% [markdown]
# ## Run Model 2

# %%
forecaster = Forecaster()
result_ts = forecaster.run_forecast_config(
     df=df_2,
     config=ForecastConfig(
         model_template=ModelTemplateEnum.SILVERKITE.name,
         forecast_horizon=100,  # forecasts 100 steps ahead
         coverage=0.95,  # 95% prediction intervals
         metadata_param=metadata,
         model_components_param=model_components,
    )
)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits

# %% [markdown]
# ### Clearly, the input timeseries is much more consistent

# %%
ts = result_ts.timeseries
fig = ts.plot()
plotly.io.show(fig)

# %% [markdown]
# # Predictions against the test set are much more closely aligned, resulting in an improved MAPE score

# %%
backtest = result_ts.backtest
fig = backtest.plot()
plotly.io.show(fig)

# %% [markdown]
# ## Final predictions

# %%
forecast = result_ts.forecast
fig = forecast.plot()
plotly.io.show(fig)

# %%
grid_search = result_ts.grid_search
cv_results = summarize_grid_search_results(
     grid_search=grid_search,
     decimals=2,
     # The below saves space in the printed output. Remove to show all available metrics and columns.
     cv_report_metrics=None,
     column_order=["rank", "mean_test", "split_test", "mean_train", "split_train", "mean_fit_time", "mean_score_time", "params"])
 # Transposes to save space in the printed output
cv_results["params"] = cv_results["params"].astype(str)
cv_results.set_index("params", drop=True, inplace=True)
cv_results.transpose()
# Out:
# params                               []
# rank_test_MAPE                        1
# mean_test_MAPE                    28.45
# split_test_MAPE   (33.89, 25.69, 25.76)
# mean_train_MAPE                   27.93
# split_train_MAPE  (33.47, 25.87, 24.46)
# mean_fit_time                      3.88
# mean_score_time                    1.15

# %% [markdown]
# ### Use the results dataframe to find the busiest day

# %%
forecast_df = forecast.__dict__['df'][['date_in','forecast']].iloc[-100:]
forecast_df
# Out:
#        date_in   forecast
# 823 2023-06-13  22.750973
# 824 2023-06-14  23.609052
# 825 2023-06-15  23.156981
# 826 2023-06-16  23.450923
# 827 2023-06-17  13.357826
# ..         ...        ...
# 918 2023-09-16  17.142967
# 919 2023-09-17  14.847092
# 920 2023-09-18  25.315023
# 921 2023-09-19  28.089701
# 922 2023-09-20  28.762099
#
# [100 rows x 2 columns]

# %%
forecast_df['day'] = forecast_df['date_in'].dt.dayofweek
forecast_df
# Out:
#        date_in   forecast  day
# 823 2023-06-13  22.750973    1
# 824 2023-06-14  23.609052    2
# 825 2023-06-15  23.156981    3
# 826 2023-06-16  23.450923    4
# 827 2023-06-17  13.357826    5
# ..         ...        ...  ...
# 918 2023-09-16  17.142967    5
# 919 2023-09-17  14.847092    6
# 920 2023-09-18  25.315023    0
# 921 2023-09-19  28.089701    1
# 922 2023-09-20  28.762099    2
#
# [100 rows x 3 columns]

# %%
dff = forecast_df.groupby(["day"]).forecast.sum().reset_index()
dff
# Out:
#    day    forecast
# 0    0  322.288739
# 1    1  380.134684
# 2    2  392.048374
# 3    3  358.505751
# 4    4  370.475271
# 5    5  215.023953
# 6    6  186.395779

# %%
print(f"Day {dff['forecast'].idxmax()} is max with predicted total of {dff['forecast'].max()}")
# Out:
# Day 2 is max with predicted total of 392.04837402652026
